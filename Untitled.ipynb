# %%
def addNum(n1,n2):
    print('Primeiro número: ' + str(n1))
    print('Segundo número: ' + str(n2))
    print(f'soma é:', {n1 + n2})

# %%
addNum(4,7)
# Out:
# Primeiro número: 4
# Segundo número: 7
# soma é: {11}

# %%
addNum(7,9)
# Out:
# Primeiro número: 7
# Segundo número: 9
# soma é: {16}
