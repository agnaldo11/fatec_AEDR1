# %%
nome = 'python' 
nome
# Out:
# 'python'

# %%
saudacao = 'ola',+ 1 
saudacao
# Out:
# ('ola', 1)

# %%
primeira_letra = nome[1:5]
primeira_letra
# Out:
# 'ytho'

# %%
numero = [1,2,3,4,5,6]
numero
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
primeiro_numero = numero[3]
primeiro_numero
# Out:
# 4

# %%
numero.append(7)
numero
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7]

# %%
numero.remove(5)
numero
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
type(10)
type(3.14)
#type('python')
type([1,2,3])
hex(255)
# Out:
# '0xff'

# %%
neme = 'joao' 
idade = 54 
altura = 1.54
print (nome)
print(idade)
print(altura)
# Out:
# python
# 54
# 1.54
